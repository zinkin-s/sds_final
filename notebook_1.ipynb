# %%
import pandas as pd
import numpy as np

df_okved_2007 = pd.read_csv('data/sheet_1.csv')
df_okved_2007.columns
# Out:
# Index(['Год', 'Всего по  экономике',
#        'Сельское хозяйство, охота и лесное хозяйство',
#        'Рыболовство, рыбоводство', 'Добыча полезных ископаемых',
#        '  добыча топливно-энергетических  полезных ископаемых',
#        '  добыча полезных ископаемых,  кроме топливно-энергетических',
#        'Обрабатывающие производства',
#        '  производство пищевых продуктов,   включая напитки, и табака',
#        '  текстильное и швейное производство',
#        '  производство кожи, изделий из   кожи и производство обуви',
#        '  обработка древесины и производство изделий из дерева',
#        '  целлюлозно-бумажное производство; издательская и полиграфическая деятельность',
#        '  производство кокса и нефтепродуктов', '  химическое производство',
#        '  производство резиновых и  пластмассовых изделий',
#        '  производство прочих неметаллических минеральных продуктов',
#        '  металлургическое производство и  производство готовых металлических изделий',
#        '  производство машин и оборудования',
#        '  производство электрооборудования, электронного и оптического оборудования',
#        '  производство транспортных средств и оборудования',
#        '  прочие производства',
#        'Производство и распределение электроэнергии, газа и воды',
#        'Строительство',
#        'Оптовая и розничная торговля; ремонт автотранспортных средств, мотоциклов, бытовых изделий и предметов личного пользования',
#        'Гостиницы и рестораны', 'Транспорт и связь', '     из них связь',
#        'Финансовая деятельность',
#        'Операции с недвижимым имуществом, аренда и предоставление услуг',
#        'Государственное управление и обеспечение военной безопасности; социальное страхование',
#        'Образование', 'Здравоохранение и предоставление социальных услуг',
#        'Предоставление прочих коммунальных, социальных и персональных услуг'],
#       dtype='object')

# %%
df_okved_2 = pd.read_csv('data/sheet_2.csv')
df_okved_2.head()
# Out:
#     Год  Всего  \
# 0  2017  39167
# 1  2018  43724
# 2  2019  47867
# 3  2020  51344
# 4  2021  57244
#
#      сельское, лесное хозяйство, охота, рыболовство и рыбоводство  \
# 0                                              25671
# 1                                              28699
# 2                                              31728
# 3                                              34770
# 4                                              39437
#
#        растениеводство и животноводство, охота и предоставление соответствующих услуг в этих областях   \
# 0                                              23529
# 1                                              25820
# 2                                              28396
# 3                                              31058
# 4                                              35460
#
#        лесоводство и лесозаготовки      рыболовство и рыбоводство  \
# 0                            27617                          68032
# 1                            32701                          75766
# 2                            35426                          88604
# 3                            37855                          94983
# 4                            42152                         101547
#
#      добыча полезных ископаемых       добыча угля  \
# 0                         74474             53065
# 1                         83178             59439
# 2                         89344             63353
# 3                         95359             62600
# 4                        103474             73577
#
#         добыча нефти и природного газа       добыча металлических руд  ...  \
# 0                               104078                          61122  ...
# 1                               127771                          70721  ...
# 2                               135364                          78520  ...
# 3                               142175                          88154  ...
# 4                               149585                          96365  ...
#
#    деятельность в области информации и связи  \
# 0                                      58811
# 1                                      66590
# 2                                      75898
# 3                                      85648
# 4                                      97434
#
#    деятельность финансовая и страховая  \
# 0                                84904
# 1                                91070
# 2                               103668
# 3                               112680
# 4                               130223
#
#    деятельность по операциям с недвижимым имуществом  \
# 0                                              30208
# 1                                              33101
# 2                                              36859
# 3                                              37628
# 4                                              43620
#
#    деятельность профессиональная,научная и техническая  \
# 0                                              57179
# 1                                              66264
# 2                                              75193
# 3                                              80077
# 4                                              87329
#
#      из нее научные исследования и разработки  \
# 0                                       66178
# 1                                       75913
# 2                                       82287
# 3                                       84973
# 4                                       93279
#
#    деятельность административная и сопутствующие дополнительные услуги  \
# 0                                              27622
# 1                                              31706
# 2                                              34002
# 3                                              37090
# 4                                              39225
#
#    государственное управление и обеспечение военной безопасности; социальное обеспечение  \
# 0                                              43500
# 1                                              47803
# 2                                              50991
# 3                                              54496
# 4                                              58620
#
#    образование  деятельность в области здравоохранения и социальных услуг  \
# 0        30258                                              31980
# 1        34361                                              40027
# 2        37072                                              43122
# 3        39563                                              49532
# 4        43391                                              50690
#
#    деятельность в области культуры, спорта, организации досуга и развлечений
# 0                                              38200
# 1                                              44439
# 2                                              46990
# 3                                              48445
# 4                                              53340
#
# [5 rows x 51 columns]

# %%
sal_1 = df_okved_2007[['Год', 'Всего по  экономике']]
sal_2 = df_okved_2[['Год', 'Всего']]
sal_2 = sal_2.rename(columns={'Всего': 'Всего по  экономике'})
table = pd.concat([sal_1, sal_2], ignore_index=True)
table
# Out:
#      Год  Всего по  экономике
# 0   2000                 2223
# 1   2001                 3240
# 2   2002                 4360
# 3   2003                 5499
# 4   2004                 6740
# 5   2005                 8555
# 6   2006                10634
# 7   2007                13593
# 8   2008                17290
# 9   2009                18638
# 10  2010                20952
# 11  2011                23369
# 12  2012                26629
# 13  2013                29792
# 14  2014                32495
# 15  2015                34030
# 16  2016                36709
# 17  2017                39167
# 18  2018                43724
# 19  2019                47867
# 20  2020                51344
# 21  2021                57244
# 22  2022                65338
# 23  2023                73709

# %%
inflation = pd.read_csv('data/inflation.csv')

# %%
inflation = inflation.set_index('Год').sort_index()
z = 100 + inflation['Всего']
table['ИПЦ'] = z
table
# Out:
#       Всего по  экономике     ИПЦ  ИНЗП к пред.году  ИРЗП к пред. году
# Год
# 2000                 2223  120.20        145.961917                NaN
# 2001                 3240  118.58        145.748988                NaN
# 2002                 4360  115.06        134.567901                NaN
# 2003                 5499  111.99        126.123853                NaN
# 2004                 6740  111.74        122.567740                NaN
# 2005                 8555  110.91        126.928783                NaN
# 2006                10634  109.00        124.301578                NaN
# 2007                13593  111.87        127.825842                NaN
# 2008                17290  113.28        127.197822                NaN
# 2009                18638  108.80        107.796414                NaN
# 2010                20952  108.78        112.415495                NaN
# 2011                23369  106.10        111.535892                NaN
# 2012                26629  106.58        113.950105                NaN
# 2013                29792  106.45        111.878028                NaN
# 2014                32495  111.36        109.072905                NaN
# 2015                34030  112.91        104.723804                NaN
# 2016                36709  105.38        107.872465                NaN
# 2017                39167  102.52        106.695906                NaN
# 2018                43724  104.27        111.634795                NaN
# 2019                47867  103.05        109.475345                NaN
# 2020                51344  104.91        107.263877                NaN
# 2021                57244  108.39        111.491119                NaN
# 2022                65338  111.92        114.139473                NaN
# 2023                73709  107.42        112.811840                NaN

# %%
xs = list(table['Всего по  экономике'])
res = []
res.append(2223 / 1523 * 100)
for i in range(1, len(xs)):
    res.append(xs[i]/xs[i-1]*100)

res = np.array(res)
table['ИНЗП к пред.году'] = res
table['ИРЗП к пред. году'] = table['ИНЗП к пред.году'] / table['ИПЦ'] * 100

arr = []
ys = list(table['ИРЗП к пред. году'])
t = 1
for j in range(len(ys)):
    t = t * (ys[j]/100)
    arr.append(t)
real_sal_temp = np.array(arr) * 100
table['ИРЗП к базовому году'] = real_sal_temp
cip = list(table['ИПЦ'])
t = 1
cip_rate = []
for i in range(len(cip)):
    t = t*cip[i]/100
    cip_rate.append(t)
cip_rate = np.array(cip_rate) * 100
table['ИПЦ к базовому году'] = cip_rate
table['РЗП к базовому году'] = table['Всего по  экономике'] / (cip_rate / 100)

table
# Out:
#       Всего по  экономике     ИПЦ  ИНЗП к пред.году  ИРЗП к пред. году  \
# Год
# 2000                 2223  120.20        145.961917         121.432543
# 2001                 3240  118.58        145.748988         122.911948
# 2002                 4360  115.06        134.567901         116.954547
# 2003                 5499  111.99        126.123853         112.620639
# 2004                 6740  111.74        122.567740         109.690120
# 2005                 8555  110.91        126.928783         114.443047
# 2006                10634  109.00        124.301578         114.038145
# 2007                13593  111.87        127.825842         114.262842
# 2008                17290  113.28        127.197822         112.286213
# 2009                18638  108.80        107.796414          99.077587
# 2010                20952  108.78        112.415495         103.342062
# 2011                23369  106.10        111.535892         105.123366
# 2012                26629  106.58        113.950105         106.915092
# 2013                29792  106.45        111.878028         105.099134
# 2014                32495  111.36        109.072905          97.946215
# 2015                34030  112.91        104.723804          92.749804
# 2016                36709  105.38        107.872465         102.365217
# 2017                39167  102.52        106.695906         104.073259
# 2018                43724  104.27        111.634795         107.063196
# 2019                47867  103.05        109.475345         106.235173
# 2020                51344  104.91        107.263877         102.243711
# 2021                57244  108.39        111.491119         102.861075
# 2022                65338  111.92        114.139473         101.983089
# 2023                73709  107.42        112.811840         105.019400
#
#       ИРЗП к базовому году  ИПЦ к базовому году  РЗП к базовому году
# Год
# 2000            121.432543           120.200000          1849.417637
# 2001            149.255105           142.533160          2273.155243
# 2002            174.560631           163.998654          2658.558407
# 2003            196.591297           183.662092          2994.085456
# 2004            215.641229           205.224022          3284.215916
# 2005            246.786393           227.613963          3758.556763
# 2006            281.430624           248.099220          4286.188411
# 2007            321.570631           277.548597          4897.520703
# 2008            361.079484           314.407051          5499.240542
# 2009            357.748838           342.074871          5448.514805
# 2010            369.705027           372.109045          5630.607557
# 2011            388.646369           394.807697          5919.084203
# 2012            415.521622           420.786043          6328.394309
# 2013            436.709625           447.926743          6651.087590
# 2014            427.740550           498.811221          6514.488577
# 2015            396.728522           563.207749          6042.175385
# 2016            406.112011           593.508326          6185.085933
# 2017            422.654007           608.464736          6437.020533
# 2018            452.506889           634.446180          6891.679918
# 2019            480.721474           653.796789          7321.388055
# 2020            491.507474           685.898211          7485.658829
# 2021            505.569869           743.445071          7699.829110
# 2022            515.595769           832.063724          7852.523569
# 2023            541.475586           893.802852          8246.673173

# %%
table[['ИНЗП к пред.году', 'ИРЗП к пред. году']].plot(kind='line')
# Out:
# <Axes: xlabel='Год'>

# %%
table[['ИРЗП к пред. году', 'ИПЦ']].plot(kind='line')
# Out:
# <Axes: xlabel='Год'>

# %%
table[['ИРЗП к базовому году', 'ИПЦ к базовому году']].plot(kind='line')
# Out:
# <Axes: xlabel='Год'>

# %%
table['Всего по  экономике'].plot()
table['РЗП к базовому году'].plot(secondary_y=True)
# Out:
# <Axes: >

# %%
cols = list(df_okved_2007.columns)
rename_cols = ['Год', 'Всего по  экономике',
       'Сельское хозяйство, охота и лесное хозяйство',
       'Рыболовство, рыбоводство', 'Добыча полезных ископаемых',
       'добыча топливно-энергетических  полезных ископаемых',
       'добыча полезных ископаемых,  кроме топливно-энергетических',
       'Обрабатывающие производства',
       'производство пищевых продуктов, включая напитки, и табака',
       'текстильное и швейное производство',
       'производство кожи, изделий из кожи и производство обуви',
       'обработка древесины и производство изделий из дерева',
       'целлюлозно-бумажное производство; издательская и полиграфическая деятельность',
       'производство кокса и нефтепродуктов', 'химическое производство',
       'производство резиновых и  пластмассовых изделий',
       'производство прочих неметаллических минеральных продуктов',
       'металлургическое производство и  производство готовых металлических изделий',
       'производство машин и оборудования',
       'производство электрооборудования, электронного и оптического оборудования',
       'производство транспортных средств и оборудования',
       'прочие производства',
       'Производство и распределение электроэнергии, газа и воды',
       'Строительство',
       'Оптовая и розничная торговля; ремонт автотранспортных средств, мотоциклов, бытовых изделий и предметов личного пользования',
       'Гостиницы и рестораны', 'Транспорт и связь', 'из них связь',
       'Финансовая деятельность',
       'Операции с недвижимым имуществом, аренда и предоставление услуг',
       'Государственное управление и обеспечение военной безопасности; социальное страхование',
       'Образование', 'Здравоохранение и предоставление социальных услуг',
       'Предоставление прочих коммунальных, социальных и персональных услуг'
]

rename_cols = [line.lower() for line in rename_cols]
d = dict(zip(cols, rename_cols))
industry_okved = df_okved_2007.rename(columns=d)
industry_okved = industry_okved.set_index('год')
industry_okved.columns
# Out:
# Index(['всего по  экономике', 'сельское хозяйство, охота и лесное хозяйство',
#        'рыболовство, рыбоводство', 'добыча полезных ископаемых',
#        'добыча топливно-энергетических  полезных ископаемых',
#        'добыча полезных ископаемых,  кроме топливно-энергетических',
#        'обрабатывающие производства',
#        'производство пищевых продуктов, включая напитки, и табака',
#        'текстильное и швейное производство',
#        'производство кожи, изделий из кожи и производство обуви',
#        'обработка древесины и производство изделий из дерева',
#        'целлюлозно-бумажное производство; издательская и полиграфическая деятельность',
#        'производство кокса и нефтепродуктов', 'химическое производство',
#        'производство резиновых и  пластмассовых изделий',
#        'производство прочих неметаллических минеральных продуктов',
#        'металлургическое производство и  производство готовых металлических изделий',
#        'производство машин и оборудования',
#        'производство электрооборудования, электронного и оптического оборудования',
#        'производство транспортных средств и оборудования',
#        'прочие производства',
#        'производство и распределение электроэнергии, газа и воды',
#        'строительство',
#        'оптовая и розничная торговля; ремонт автотранспортных средств, мотоциклов, бытовых изделий и предметов личного пользования',
#        'гостиницы и рестораны', 'транспорт и связь', 'из них связь',
#        'финансовая деятельность',
#        'операции с недвижимым имуществом, аренда и предоставление услуг',
#        'государственное управление и обеспечение военной безопасности; социальное страхование',
#        'образование', 'здравоохранение и предоставление социальных услуг',
#        'предоставление прочих коммунальных, социальных и персональных услуг'],
#       dtype='object')

# %%
def salary_index(df, ind_selector):
    res = []
    arr = list(df[ind_selector])
    for i in range(1, len(arr)):
        res.append(arr[i]/arr[i-1]*100)
    data = pd.DataFrame()
    data['НСЗП'] = df[ind_selector].iloc[1:]
   
    res = np.array(res)
    data['ИНЗП к пред.году'] = res
    z = table['ИПЦ'][1:17]
    data = data.merge(z, left_index=True, right_index=True)
    data['ИРЗП к пред.году'] = data['ИНЗП к пред.году'] / data['ИПЦ'] * 100

    arr = []
    ys = list(data['ИРЗП к пред.году'])
    t = 1
    for j in range(len(ys)):
        t = t * (ys[j] / 100)
        arr.append(t)
    real_sal_temp = np.array(arr) * 100
    data['ИРЗП к базовому году'] = real_sal_temp
    return data


selector = 'сельское хозяйство, охота и лесное хозяйство'
df = salary_index(industry_okved, selector)
df[['ИНЗП к пред.году', 'ИРЗП к пред.году']].plot(kind='line')
# Out:
# <Axes: xlabel='год'>

# %%
df[['ИНЗП к пред.году', 'ИПЦ']].plot(kind='line')
# Out:
# <Axes: xlabel='год'>

# %%
df['ИРЗП к базовому году'].plot(kind='line')
# Out:
# <Axes: xlabel='год'>
